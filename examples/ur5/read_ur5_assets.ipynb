# %%
import json
from pathlib import Path

# %%
assets_dir = Path("/mnt/22TB_IndEgo/yahuan/openpi/examples/ur5")

# 读取 norm_stats.json
with open("/mnt/4TBSSD/users/yahuanshi/OpenPi/Fine-Tuning-Pi0.5/examples/ur5/read_ur5_assets.ipynb") as f:
    norm_stats = json.load(f)

# %%
# 查看关节归一化信息
print("Joint mean:", norm_stats.get("joint_mean"))
print("Joint std:", norm_stats.get("joint_std"))
print("Workspace scale:", norm_stats.get("workspace_scale"))
# Out:
# Joint mean: None
# Joint std: None
# Workspace scale: None
